# %%
import networkx as nx
import pandas as pd
from community import community_louvain  # Install this using pip if not already installed

# List of file paths
file_paths = [
    'datacleaning/aishihik_lake_preprocessed.csv',
    'datacleaning/AkatoreA_preprocessed.csv',
    'datacleaning/AkatoreB_preprocessed.csv',
    'datacleaning/cold_lake_preprocessed.csv',
    'datacleaning/lake_of_the_woods_preprocessed.csv',
    'datacleaning/mcgregor_river_preprocessed.csv',
    'datacleaning/parsnip_river_preprocessed.csv',
    'datacleaning/sbay_lake_huron_preprocessed.csv',
    'datacleaning/smallwood_reservoir_preprocessed.csv',
    'datacleaning/Venlaw_preprocessed.csv'
]

# Function to calculate network properties, link prediction, and community detection
def calculate_network_properties(file_path):
    # Read the CSV into a pandas DataFrame
    edge_list = pd.read_csv(file_path)
    
    # Create a graph from the edge list (assuming the CSV has columns 'source' and 'target')
    G = nx.from_pandas_edgelist(edge_list, source='source', target='target')
    
    # Calculate network properties
    num_nodes = G.number_of_nodes()
    num_edges = G.number_of_edges()
    degree_distribution = [degree for node, degree in G.degree()]
    mean_degree = sum(degree_distribution) / num_nodes
    clustering_coeff = nx.average_clustering(G)
    
    # Check connectivity for MGD
    if nx.is_connected(G):
        mean_geodesic_distance = nx.average_shortest_path_length(G)
    else:
        mean_geodesic_distance = None  # Not applicable for disconnected graphs
    
    # Link Prediction (using Common Neighbors as an example)
    link_pred_scores = []
    for u, v in nx.non_edges(G):  # All pairs of nodes that are not connected
        score = len(list(nx.common_neighbors(G, u, v)))  # Direct import from base networkx
        link_pred_scores.append((u, v, score))
    
    # Sort by prediction score
    link_pred_scores_sorted = sorted(link_pred_scores, key=lambda x: x[2], reverse=True)
    
    # Community Detection using Louvain Method
    partition = community_louvain.best_partition(G)
    num_communities = len(set(partition.values()))
    
    # Create a mapping of nodes to their communities
    community_mapping = {node: f"Community {comm}" for node, comm in partition.items()}
    
    # Return the results as a formatted string
    results = f"""
    Results for {file_path}:
    ------------------------------
      Number of nodes (species): {num_nodes}
      Number of edges (interactions): {num_edges}
      Degree distribution: {degree_distribution}
      Mean degree: {mean_degree}
      Clustering coefficient: {clustering_coeff}
    """
    if mean_geodesic_distance is not None:
        results += f"      Mean geodesic distance (MGD): {mean_geodesic_distance}\n"
    else:
        results += "      Graph is not connected, MGD cannot be computed.\n"
    
    # Display the top 5 predicted links
    results += "\nTop 5 Predicted Links (based on Common Neighbors):\n"
    for u, v, score in link_pred_scores_sorted[:5]:
        results += f"      ({u}, {v}) - Prediction Score: {score}\n"
    
    # Display community detection results
    results += f"\nNumber of communities detected: {num_communities}\n"
    results += f"Node to Community Mapping (first 10 nodes): {list(community_mapping.items())[:10]}\n"
    
    results += "-" * 50 + "\n"
    
    return results

# Loop through all files and calculate properties, printing the results
for file_path in file_paths:
    result = calculate_network_properties(file_path)
    print(result)
# Out:
#     Results for datacleaning/aishihik_lake_preprocessed.csv:
#     ------------------------------
#       Number of nodes (species): 39
#       Number of edges (interactions): 248
#       Degree distribution: [31, 8, 31, 31, 31, 31, 31, 31, 31, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8]
#       Mean degree: 12.717948717948717
#       Clustering coefficient: 0.0
#           Mean geodesic distance (MGD): 1.6653171390013495
#
# Top 5 Predicted Links (based on Common Neighbors):
#       (Thymallus arcticus, Catostomus catostomus) - Prediction Score: 31
#       (Thymallus arcticus, Esox lucius) - Prediction Score: 31
#       (Thymallus arcticus, Prosopium cylindraceum) - Prediction Score: 31
#       (Thymallus arcticus, Coregonus clupeaformis) - Prediction Score: 31
#       (Thymallus arcticus, Cottus cognatus) - Prediction Score: 31
#
# Number of communities detected: 1
# Node to Community Mapping (first 10 nodes): [('Host species', 'Community 0'), ('Unnamed: 1', 'Community 0'), ('Catostomus catostomus', 'Community 0'), ('Coregonus clupeaformis', 'Community 0'), ('Cottus cognatus', 'Community 0'), ('Esox lucius', 'Community 0'), ('Prosopium cylindraceum', 'Community 0'), ('Salvelinus namaycush', 'Community 0'), ('Thymallus arcticus', 'Community 0'), ('Parasite genus', 'Community 0')]
# --------------------------------------------------
#
#
#     Results for datacleaning/AkatoreA_preprocessed.csv:
#     ------------------------------
#       Number of nodes (species): 126
#       Number of edges (interactions): 6279
#       Degree distribution: [127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85]
#       Mean degree: 99.66666666666667
#       Clustering coefficient: 0.7766214155913242
#           Mean geodesic distance (MGD): 1.2082539682539684
#
# Top 5 Predicted Links (based on Common Neighbors):
#       (Sphaerid (N=1), Paucispinigera approximata (N=1)) - Prediction Score: 85
#       (Sphaerid (N=1), Anguilla dieffenbachii (N=1)) - Prediction Score: 85
#       (Sphaerid (N=1), Paracalliope fluviatalus (N=10)) - Prediction Score: 85
#       (Sphaerid (N=1), Neozephlebia scita (N=10)) - Prediction Score: 85
#       (Sphaerid (N=1), Hydrobiosella stenocerca (N=15)) - Prediction Score: 85
#
# Number of communities detected: 44
# Node to Community Mapping (first 10 nodes): [('Unidentified detritus', 'Community 30'), ('Terrestrial invertebrates', 'Community 39'), ('Plant materials', 'Community 3'), ('Meiofauna', 'Community 4'), ('Achnanthes inflata', 'Community 12'), ('Achnanthes lanceolata', 'Community 38'), ('Achnanthes linearis', 'Community 33'), ('Achnanthes minutissima', 'Community 6'), ('Ankitodesmus sp.', 'Community 31'), ('Batrachospermum', 'Community 14')]
# --------------------------------------------------
#
#
#     Results for datacleaning/AkatoreB_preprocessed.csv:
#     ------------------------------
#       Number of nodes (species): 88
#       Number of edges (interactions): 2986
#       Degree distribution: [89, 89, 58, 89, 89, 89, 89, 89, 89, 89, 89, 89, 89, 89, 89, 89, 89, 89, 89, 89, 89, 89, 89, 89, 89, 89, 89, 89, 89, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58]
#       Mean degree: 67.86363636363636
#       Clustering coefficient: 0.7465783910092355
#           Mean geodesic distance (MGD): 1.2272727272727273
#
# Top 5 Predicted Links (based on Common Neighbors):
#       (Aspectrotanypus (N=Larsia), Paralimnophila (N=1)) - Prediction Score: 58
#       (Aspectrotanypus (N=Larsia), Oligochaeta lumbr blue (N=10)) - Prediction Score: 58
#       (Aspectrotanypus (N=Larsia), Tanytarsus verspertinus (N=3)) - Prediction Score: 58
#       (Aspectrotanypus (N=Larsia), Paracalliope fluviatalus (N=10)) - Prediction Score: 58
#       (Aspectrotanypus (N=Larsia), Ameletopsis perscitus (N=10)) - Prediction Score: 58
#
# Number of communities detected: 28
# Node to Community Mapping (first 10 nodes): [('Unidentified detritus', 'Community 0'), ('Plant material', 'Community 1'), ('Terrestrial invertebrates', 'Community 2'), ('Achnanthes inflata', 'Community 3'), ('Achnanthes lanceolata', 'Community 4'), ('Achnanthes linearis', 'Community 5'), ('Achnanthes minutissima', 'Community 6'), ('Blue green algae', 'Community 2'), ('Calothrix', 'Community 15'), ('Cocconeis placentula', 'Community 8')]
# --------------------------------------------------
#
#
#     Results for datacleaning/cold_lake_preprocessed.csv:
#     ------------------------------
#       Number of nodes (species): 54
#       Number of edges (interactions): 473
#       Degree distribution: [43, 11, 43, 43, 43, 43, 43, 43, 43, 43, 43, 43, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11]
#       Mean degree: 17.51851851851852
#       Clustering coefficient: 0.0
#           Mean geodesic distance (MGD): 1.6694619147449337
#
# Top 5 Predicted Links (based on Common Neighbors):
#       (Catostomus commersoni, Catostomus catostomus) - Prediction Score: 43
#       (Catostomus commersoni, Esox lucius) - Prediction Score: 43
#       (Catostomus commersoni, Pungitius pungitius) - Prediction Score: 43
#       (Catostomus commersoni, Oncorhynchus kisutch) - Prediction Score: 43
#       (Catostomus commersoni, Coregonus artedii) - Prediction Score: 43
#
# Number of communities detected: 1
# Node to Community Mapping (first 10 nodes): [('Host species', 'Community 0'), ('Unnamed: 1', 'Community 0'), ('Coregonus artedii', 'Community 0'), ('Coregonus clupeaformis', 'Community 0'), ('Salvelinus namaycush', 'Community 0'), ('Oncorhynchus kisutch', 'Community 0'), ('Esox lucius', 'Community 0'), ('Catostomus catostomus', 'Community 0'), ('Catostomus commersoni', 'Community 0'), ('Lota lota', 'Community 0')]
# --------------------------------------------------
#
#
#     Results for datacleaning/lake_of_the_woods_preprocessed.csv:
#     ------------------------------
#       Number of nodes (species): 178
#       Number of edges (interactions): 4672
#       Degree distribution: [146, 32, 146, 146, 146, 146, 146, 146, 146, 146, 146, 146, 146, 146, 146, 146, 146, 146, 146, 146, 146, 146, 146, 146, 146, 146, 146, 146, 146, 146, 146, 146, 146, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32]
#       Mean degree: 52.49438202247191
#       Clustering coefficient: 0.0
#           Mean geodesic distance (MGD): 1.703421570494509
#
# Top 5 Predicted Links (based on Common Neighbors):
#       (Semotilus margarita, Catostomus commersoni) - Prediction Score: 146
#       (Semotilus margarita, Pimephales promelas) - Prediction Score: 146
#       (Semotilus margarita, Micropterus dolomieui) - Prediction Score: 146
#       (Semotilus margarita, Etheostoma exile) - Prediction Score: 146
#       (Semotilus margarita, Percopsis omiscomaycus) - Prediction Score: 146
#
# Number of communities detected: 2
# Node to Community Mapping (first 10 nodes): [('Host species', 'Community 0'), ('Unnamed: 1', 'Community 1'), ('Salvelinus namaycush', 'Community 0'), ('Coregonus clupeaformis', 'Community 0'), ('Coregonus artedii', 'Community 0'), ('Esox lucius', 'Community 1'), ('Carpiodes cyprinus', 'Community 0'), ('Catostomus commersoni', 'Community 1'), ('Moxostoma anisurum', 'Community 1'), ('Chrosomus neogaeus', 'Community 1')]
# --------------------------------------------------
#
#
#     Results for datacleaning/mcgregor_river_preprocessed.csv:
#     ------------------------------
#       Number of nodes (species): 69
#       Number of edges (interactions): 848
#       Degree distribution: [53, 16, 53, 53, 53, 53, 53, 53, 53, 53, 53, 53, 53, 53, 53, 53, 53, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16]
#       Mean degree: 24.579710144927535
#       Clustering coefficient: 0.0
#           Mean geodesic distance (MGD): 1.6385336743393009
#
# Top 5 Predicted Links (based on Common Neighbors):
#       (Rhinichthys cataractae, Catostomus catostomus) - Prediction Score: 53
#       (Rhinichthys cataractae, Catostomus macrocheilus) - Prediction Score: 53
#       (Rhinichthys cataractae, Oncorhynchus nerka) - Prediction Score: 53
#       (Rhinichthys cataractae, Cottus asper) - Prediction Score: 53
#       (Rhinichthys cataractae, Cottus cognatus) - Prediction Score: 53
#
# Number of communities detected: 1
# Node to Community Mapping (first 10 nodes): [('Host species', 'Community 0'), ('Unnamed: 1', 'Community 0'), ('Catostomus catostomus', 'Community 0'), ('Catostomus macrocheilus', 'Community 0'), ('Cottus asper', 'Community 0'), ('Cottus cognatus', 'Community 0'), ('Lota lota', 'Community 0'), ('Mylocheilus caurinus', 'Community 0'), ('Oncorhynchus nerka', 'Community 0'), ('Oncorhynchus tshawytscha', 'Community 0')]
# --------------------------------------------------
#
#
#     Results for datacleaning/parsnip_river_preprocessed.csv:
#     ------------------------------
#       Number of nodes (species): 73
#       Number of edges (interactions): 990
#       Degree distribution: [55, 18, 55, 55, 55, 55, 55, 55, 55, 55, 55, 55, 55, 55, 55, 55, 55, 55, 55, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18]
#       Mean degree: 27.123287671232877
#       Clustering coefficient: 0.0
#           Mean geodesic distance (MGD): 1.6232876712328768
#
# Top 5 Predicted Links (based on Common Neighbors):
#       (Catostomus commersoni, Catostomus catostomus) - Prediction Score: 55
#       (Catostomus commersoni, Rhinichthys cataractae) - Prediction Score: 55
#       (Catostomus commersoni, Catostomus macrocheilus) - Prediction Score: 55
#       (Catostomus commersoni, Oncorhynchus nerka) - Prediction Score: 55
#       (Catostomus commersoni, Coregonus clupeaformis) - Prediction Score: 55
#
# Number of communities detected: 1
# Node to Community Mapping (first 10 nodes): [('Host species', 'Community 0'), ('Unnamed: 1', 'Community 0'), ('Catostomus catostomus', 'Community 0'), ('Catostomus commersoni', 'Community 0'), ('Catostomus macrocheilus', 'Community 0'), ('Coregonus clupeaformis', 'Community 0'), ('Cottus cognatus', 'Community 0'), ('Lota lota', 'Community 0'), ('Mylocheilus caurinus', 'Community 0'), ('Oncorhynchus nerka', 'Community 0')]
# --------------------------------------------------
#
#
#     Results for datacleaning/sbay_lake_huron_preprocessed.csv:
#     ------------------------------
#       Number of nodes (species): 133
#       Number of edges (interactions): 3366
#       Degree distribution: [99, 34, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34]
#       Mean degree: 50.61654135338346
#       Clustering coefficient: 0.0
#           Mean geodesic distance (MGD): 1.6165413533834587
#
# Top 5 Predicted Links (based on Common Neighbors):
#       (Esox lucius, Catostomus commersoni) - Prediction Score: 99
#       (Esox lucius, Rhinichthys cataractae) - Prediction Score: 99
#       (Esox lucius, Coregonus hoyi) - Prediction Score: 99
#       (Esox lucius, Etheostoma exile) - Prediction Score: 99
#       (Esox lucius, Micropterus dolomieui) - Prediction Score: 99
#
# Number of communities detected: 1
# Node to Community Mapping (first 10 nodes): [('Host species', 'Community 0'), ('Unnamed: 1', 'Community 0'), ('Osmerus mordax', 'Community 0'), ('Coregonus artedi', 'Community 0'), ('Coregonus hoyi', 'Community 0'), ('Coregonus clupeaformis', 'Community 0'), ('Prosopium cylindraceum', 'Community 0'), ('Oncorhynchus mykiss', 'Community 0'), ('Salvelinus fontinalis', 'Community 0'), ('Salvelinus namaycush', 'Community 0')]
# --------------------------------------------------
#
#
#     Results for datacleaning/smallwood_reservoir_preprocessed.csv:
#     ------------------------------
#       Number of nodes (species): 34
#       Number of edges (interactions): 189
#       Degree distribution: [27, 7, 27, 27, 27, 27, 27, 27, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7]
#       Mean degree: 11.117647058823529
#       Clustering coefficient: 0.0
#           Mean geodesic distance (MGD): 1.6631016042780749
#
# Top 5 Predicted Links (based on Common Neighbors):
#       (Salmo salar, Catostomus catostomus) - Prediction Score: 27
#       (Salmo salar, Esox lucius) - Prediction Score: 27
#       (Salmo salar, Coregonus clupeaformis) - Prediction Score: 27
#       (Salmo salar, Salvelinus namaycush) - Prediction Score: 27
#       (Salmo salar, Host species) - Prediction Score: 27
#
# Number of communities detected: 1
# Node to Community Mapping (first 10 nodes): [('Host species', 'Community 0'), ('Unnamed: 1', 'Community 0'), ('Salmo salar', 'Community 0'), ('Salvelinus fontinalis', 'Community 0'), ('Salvelinus namaycush', 'Community 0'), ('Coregonus clupeaformis', 'Community 0'), ('Esox lucius', 'Community 0'), ('Catostomus catostomus', 'Community 0'), ('Parasite genus', 'Community 0'), ('Tetraonchus', 'Community 0')]
# --------------------------------------------------
#
#
#     Results for datacleaning/Venlaw_preprocessed.csv:
#     ------------------------------
#       Number of nodes (species): 106
#       Number of edges (interactions): 4265
#       Degree distribution: [107, 107, 107, 107, 107, 107, 107, 107, 107, 107, 107, 107, 107, 107, 107, 107, 107, 107, 107, 107, 107, 107, 107, 107, 107, 107, 107, 107, 107, 107, 107, 69, 69, 69, 69, 69, 69, 107, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69]
#       Mean degree: 80.47169811320755
#       Clustering coefficient: 0.7281673015012791
#           Mean geodesic distance (MGD): 1.2393530997304583
#
# Top 5 Predicted Links (based on Common Neighbors):
#       (Pycnocentria evecta (N=4), Salmo trutta (N=3)) - Prediction Score: 69
#       (Pycnocentria evecta (N=4), Amphipoda type 'purple' (N=6)) - Prediction Score: 69
#       (Pycnocentria evecta (N=4), Ameletopsis perscitus (N=1)) - Prediction Score: 69
#       (Pycnocentria evecta (N=4), Maoridiamesia sp. (N=10)) - Prediction Score: 69
#       (Pycnocentria evecta (N=4), Hydora nitida (N=10)) - Prediction Score: 69
#
# Number of communities detected: 32
# Node to Community Mapping (first 10 nodes): [('Terrestrial invertebrate remains', 'Community 0'), ('Terrestrial plant material', 'Community 20'), ('Unidentified organic detritus', 'Community 2'), ('Achnanthes lanceolata', 'Community 3'), ('Cocconeis placentual', 'Community 4'), ('Cymbella aspera', 'Community 5'), ('Epithemis turgida', 'Community 6'), ('Fragilaria vaucheriae', 'Community 7'), ('Frustulia rhomboides', 'Community 8'), ('Gomphoneis herculeana var. robusta', 'Community 9')]
# --------------------------------------------------

# %%
import networkx as nx
import pandas as pd
import numpy as np
from itertools import permutations
import random
from multiprocessing import Pool, cpu_count
from functools import partial

def sample_motifs(G, sample_size=1000):
    """
    Sample network motifs using a faster sampling approach
    """
    nodes = list(G.nodes())
    n = len(nodes)
    if n < 3:
        return [], []
    
    # Pre-compute adjacency for faster lookup
    adj = {node: set(G.successors(node)) for node in G.nodes()}
    
    ffls = set()
    fbls = set()
    
    # Sample random node triplets instead of checking all combinations
    samples = [random.sample(nodes, 3) for _ in range(sample_size)]
    
    for nodes in samples:
        # Check for feed-forward loops
        if (nodes[1] in adj[nodes[0]] and 
            nodes[2] in adj[nodes[1]] and 
            nodes[2] in adj[nodes[0]]):
            ffls.add(tuple(sorted(nodes)))
            
        # Check for feedback loops
        if (nodes[1] in adj[nodes[0]] and 
            nodes[2] in adj[nodes[1]] and 
            nodes[0] in adj[nodes[2]]):
            fbls.add(tuple(sorted(nodes)))
    
    # Extrapolate counts based on sampling ratio
    total_combinations = n * (n-1) * (n-2)
    scaling_factor = total_combinations / sample_size
    
    return list(ffls), list(fbls), scaling_factor

def generate_random_network(args):
    """
    Generate a single random network (for parallel processing)
    """
    G, seed = args
    random.seed(seed)
    try:
        RG = nx.directed_configuration_model(
            [d for _, d in G.in_degree()],
            [d for _, d in G.out_degree()]
        )
        RG = nx.DiGraph(RG)
        RG.remove_edges_from(nx.selfloop_edges(RG))
        return RG
    except:
        return nx.gnm_random_graph(G.number_of_nodes(), G.number_of_edges(), directed=True)

def calculate_network_properties(file_path):
    """
    Calculate network properties with optimized motif analysis
    """
    # Read and create network
    edge_list = pd.read_csv(file_path)
    G = nx.from_pandas_edgelist(edge_list, source='source', target='target', create_using=nx.DiGraph())
    
    # Basic network metrics
    n_nodes = G.number_of_nodes()
    n_edges = G.number_of_edges()
    mean_degree = 2 * n_edges / n_nodes
    clustering_coeff = nx.average_clustering(G.to_undirected())
    
    # Motif sampling
    ffls, fbls, scaling_factor = sample_motifs(G, sample_size=1000)
    
    # Parallel random network generation (reduced to 100 networks)
    n_random = 100
    with Pool(processes=cpu_count()) as pool:
        random_networks = pool.map(
            generate_random_network,
            [(G, i) for i in range(n_random)]
        )
    
    # Calculate motif statistics for random networks
    random_ffl_counts = []
    random_fbl_counts = []
    
    for RG in random_networks:
        rand_ffls, rand_fbls, rand_scale = sample_motifs(RG, sample_size=1000)
        random_ffl_counts.append(len(rand_ffls) * rand_scale)
        random_fbl_counts.append(len(rand_fbls) * rand_scale)
    
    # Calculate statistics
    ffl_stats = {
        'count': len(ffls) * scaling_factor,
        'mean_random': np.mean(random_ffl_counts),
        'std_random': np.std(random_ffl_counts),
        'z_score': (len(ffls) * scaling_factor - np.mean(random_ffl_counts)) / (np.std(random_ffl_counts) + 1e-10),
        'p_value': sum(count >= len(ffls) * scaling_factor for count in random_ffl_counts) / len(random_ffl_counts)
    }
    
    fbl_stats = {
        'count': len(fbls) * scaling_factor,
        'mean_random': np.mean(random_fbl_counts),
        'std_random': np.std(random_fbl_counts),
        'z_score': (len(fbls) * scaling_factor - np.mean(random_fbl_counts)) / (np.std(random_fbl_counts) + 1e-10),
        'p_value': sum(count >= len(fbls) * scaling_factor for count in random_fbl_counts) / len(random_fbl_counts)
    }
    
    results = f"""
    Results for {file_path}:
    ------------------------------
    Network Properties:
      Nodes: {n_nodes}
      Edges: {n_edges}
      Mean Degree: {mean_degree:.2f}
      Clustering Coefficient: {clustering_coeff:.4f}
    
    Motif Analysis (Estimated):
      Feed-Forward Loops (FFL):
        Estimated Count: {ffl_stats['count']:.1f}
        Random Mean: {ffl_stats['mean_random']:.1f} ± {ffl_stats['std_random']:.1f}
        Z-score: {ffl_stats['z_score']:.4f}
        P-value: {ffl_stats['p_value']:.4f}
        
      Feedback Loops (FBL):
        Estimated Count: {fbl_stats['count']:.1f}
        Random Mean: {fbl_stats['mean_random']:.1f} ± {fbl_stats['std_random']:.1f}
        Z-score: {fbl_stats['z_score']:.4f}
        P-value: {fbl_stats['p_value']:.4f}
    ------------------------------
    """
    
    return results

# File paths
file_paths = [
    'datacleaning/aishihik_lake_preprocessed.csv',
    'datacleaning/AkatoreA_preprocessed.csv',
    'datacleaning/AkatoreB_preprocessed.csv',
    'datacleaning/cold_lake_preprocessed.csv',
    'datacleaning/lake_of_the_woods_preprocessed.csv',
    'datacleaning/mcgregor_river_preprocessed.csv',
    'datacleaning/parsnip_river_preprocessed.csv',
    'datacleaning/sbay_lake_huron_preprocessed.csv',
    'datacleaning/smallwood_reservoir_preprocessed.csv',
    'datacleaning/Venlaw_preprocessed.csv'
]

# Process all files
for file_path in file_paths:
    result = calculate_network_properties(file_path)
    print(result)
# Out:
#     Results for datacleaning/aishihik_lake_preprocessed.csv:
#     ------------------------------
#     Network Properties:
#       Nodes: 39
#       Edges: 248
#       Mean Degree: 12.72
#       Clustering Coefficient: 0.0000
#
#     Motif Analysis (Estimated):
#       Feed-Forward Loops (FFL):
#         Estimated Count: 0.0
#         Random Mean: 0.0 ± 0.0
#         Z-score: 0.0000
#         P-value: 1.0000
#
#       Feedback Loops (FBL):
#         Estimated Count: 0.0
#         Random Mean: 0.0 ± 0.0
#         Z-score: 0.0000
#         P-value: 1.0000
#     ------------------------------
#
#
#     Results for datacleaning/AkatoreA_preprocessed.csv:
#     ------------------------------
#     Network Properties:
#       Nodes: 126
#       Edges: 7225
#       Mean Degree: 114.68
#       Clustering Coefficient: 0.7766
#
#     Motif Analysis (Estimated):
#       Feed-Forward Loops (FFL):
#         Estimated Count: 277326.0
#         Random Mean: 79369.9 ± 12733.6
#         Z-score: 15.5460
#         P-value: 0.0000
#
#       Feedback Loops (FBL):
#         Estimated Count: 78120.0
#         Random Mean: 20643.2 ± 6467.1
#         Z-score: 8.8876
#         P-value: 0.0000
#     ------------------------------
#
#
#     Results for datacleaning/AkatoreB_preprocessed.csv:
#     ------------------------------
#     Network Properties:
#       Nodes: 88
#       Edges: 3364
#       Mean Degree: 76.45
#       Clustering Coefficient: 0.7466
#
#     Motif Analysis (Estimated):
#       Feed-Forward Loops (FFL):
#         Estimated Count: 96128.7
#         Random Mean: 23979.5 ± 4110.9
#         Z-score: 17.5505
#         P-value: 0.0000
#
#       Feedback Loops (FBL):
#         Estimated Count: 22386.1
#         Random Mean: 5135.6 ± 1701.7
#         Z-score: 10.1371
#         P-value: 0.0000
#     ------------------------------
#
#
#     Results for datacleaning/cold_lake_preprocessed.csv:
#     ------------------------------
#     Network Properties:
#       Nodes: 54
#       Edges: 473
#       Mean Degree: 17.52
#       Clustering Coefficient: 0.0000
#
#     Motif Analysis (Estimated):
#       Feed-Forward Loops (FFL):
#         Estimated Count: 0.0
#         Random Mean: 0.0 ± 0.0
#         Z-score: 0.0000
#         P-value: 1.0000
#
#       Feedback Loops (FBL):
#         Estimated Count: 0.0
#         Random Mean: 0.0 ± 0.0
#         Z-score: 0.0000
#         P-value: 1.0000
#     ------------------------------
#
#
#     Results for datacleaning/lake_of_the_woods_preprocessed.csv:
#     ------------------------------
#     Network Properties:
#       Nodes: 178
#       Edges: 4672
#       Mean Degree: 52.49
#       Clustering Coefficient: 0.0000
#
#     Motif Analysis (Estimated):
#       Feed-Forward Loops (FFL):
#         Estimated Count: 0.0
#         Random Mean: 0.0 ± 0.0
#         Z-score: 0.0000
#         P-value: 1.0000
#
#       Feedback Loops (FBL):
#         Estimated Count: 0.0
#         Random Mean: 0.0 ± 0.0
#         Z-score: 0.0000
#         P-value: 1.0000
#     ------------------------------
#
#
#     Results for datacleaning/mcgregor_river_preprocessed.csv:
#     ------------------------------
#     Network Properties:
#       Nodes: 69
#       Edges: 848
#       Mean Degree: 24.58
#       Clustering Coefficient: 0.0000
#
#     Motif Analysis (Estimated):
#       Feed-Forward Loops (FFL):
#         Estimated Count: 0.0
#         Random Mean: 0.0 ± 0.0
#         Z-score: 0.0000
#         P-value: 1.0000
#
#       Feedback Loops (FBL):
#         Estimated Count: 0.0
#         Random Mean: 0.0 ± 0.0
#         Z-score: 0.0000
#         P-value: 1.0000
#     ------------------------------
#
#
#     Results for datacleaning/parsnip_river_preprocessed.csv:
#     ------------------------------
#     Network Properties:
#       Nodes: 73
#       Edges: 990
#       Mean Degree: 27.12
#       Clustering Coefficient: 0.0000
#
#     Motif Analysis (Estimated):
#       Feed-Forward Loops (FFL):
#         Estimated Count: 0.0
#         Random Mean: 0.0 ± 0.0
#         Z-score: 0.0000
#         P-value: 1.0000
#
#       Feedback Loops (FBL):
#         Estimated Count: 0.0
#         Random Mean: 0.0 ± 0.0
#         Z-score: 0.0000
#         P-value: 1.0000
#     ------------------------------
#
#
#     Results for datacleaning/sbay_lake_huron_preprocessed.csv:
#     ------------------------------
#     Network Properties:
#       Nodes: 133
#       Edges: 3366
#       Mean Degree: 50.62
#       Clustering Coefficient: 0.0000
#
#     Motif Analysis (Estimated):
#       Feed-Forward Loops (FFL):
#         Estimated Count: 0.0
#         Random Mean: 0.0 ± 0.0
#         Z-score: 0.0000
#         P-value: 1.0000
#
#       Feedback Loops (FBL):
#         Estimated Count: 0.0
#         Random Mean: 0.0 ± 0.0
#         Z-score: 0.0000
#         P-value: 1.0000
#     ------------------------------
#
#
#     Results for datacleaning/smallwood_reservoir_preprocessed.csv:
#     ------------------------------
#     Network Properties:
#       Nodes: 34
#       Edges: 189
#       Mean Degree: 11.12
#       Clustering Coefficient: 0.0000
#
#     Motif Analysis (Estimated):
#       Feed-Forward Loops (FFL):
#         Estimated Count: 0.0
#         Random Mean: 0.0 ± 0.0
#         Z-score: 0.0000
#         P-value: 1.0000
#
#       Feedback Loops (FBL):
#         Estimated Count: 0.0
#         Random Mean: 0.0 ± 0.0
#         Z-score: 0.0000
#         P-value: 1.0000
#     ------------------------------
#
#
#     Results for datacleaning/Venlaw_preprocessed.csv:
#     ------------------------------
#     Network Properties:
#       Nodes: 106
#       Edges: 4761
#       Mean Degree: 89.83
#       Clustering Coefficient: 0.7282
#
#     Motif Analysis (Estimated):
#       Feed-Forward Loops (FFL):
#         Estimated Count: 140059.9
#         Random Mean: 38105.6 ± 6952.2
#         Z-score: 14.6650
#         P-value: 0.0000
#
#       Feedback Loops (FBL):
#         Estimated Count: 34725.6
#         Random Mean: 7905.9 ± 3441.8
#         Z-score: 7.7924
#         P-value: 0.0000
#     ------------------------------
