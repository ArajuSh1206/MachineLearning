# %%
import pandas as pd
import networkx as nx
import os

# List of dataset file paths
file_paths = [
    "Datasets/aishihik_lake.csv",
    "Datasets/cold_lake.csv",
    "Datasets/lake_of_the_woods.csv",
    "Datasets/mcgregor_river.csv",
    "Datasets/parsnip_river.csv",
    "Datasets/sbay_lake_huron.csv",
    "Datasets/smallwood_reservoir.csv",
]

# Ensure the output directory exists
output_dir = "datacleaning"
os.makedirs(output_dir, exist_ok=True)

# Loop through each dataset and preprocess
for file_path in file_paths:
    try:
        # Load the dataset
        data = pd.read_csv(file_path)
        print(f"Dataset '{file_path}' loaded successfully.")
        
        # Check columns in the dataset
        print(f"Columns in '{file_path}': {data.columns.tolist()}")
        
        # Step 1: Handle missing or incorrect 'Parasite genus' column
        # If 'Unnamed: 0' is the column holding genus names, use it as the source
        if 'Unnamed: 0' not in data.columns:
            print(f"Error: 'Unnamed: 0' column not found in {file_path}. Skipping this dataset.")
            continue
        
        # Step 2: Restructure data into long format (using the first column for the 'source')
        data_long = data.melt(id_vars=["Unnamed: 0"], 
                              var_name="target", 
                              value_name="weight")
        
        # Rename columns for clarity
        data_long = data_long.rename(columns={"Unnamed: 0": "source"})
        
        # Step 3: Drop rows with missing values
        data_long = data_long.dropna()
        print(f"Rows after removing missing values: {len(data_long)}")
        
        # Step 4: Drop duplicate edges
        data_long = data_long.drop_duplicates(subset=["source", "target"])
        print(f"Rows after removing duplicate edges: {len(data_long)}")
        
        # Step 5: Create a directed graph
        G = nx.from_pandas_edgelist(data_long, source="source", target="target", create_using=nx.DiGraph())
        print(f"Graph created for '{file_path}' with {G.number_of_nodes()} nodes and {G.number_of_edges()} edges.")
        
        # Step 6: Calculate clustering coefficient
        # If the graph is directed, we calculate the clustering coefficient for the directed graph
        if isinstance(G, nx.DiGraph):
            clustering_coeffs = nx.clustering(G.to_undirected())  # Convert to undirected for clustering
        else:
            clustering_coeffs = nx.clustering(G)  # For undirected graphs
        
        # Calculate the average clustering coefficient
        avg_clustering_coeff = sum(clustering_coeffs.values()) / len(clustering_coeffs)
        print(f"Clustering coefficient for '{file_path}': {avg_clustering_coeff}")
        
        # Step 7: Save the preprocessed data
        output_path = os.path.join(output_dir, f"{file_path.split('/')[-1].replace('.csv', '_preprocessed.csv')}")
        data_long.to_csv(output_path, index=False)
        print(f"Preprocessed data saved to {output_path}")
    
    except Exception as e:
        print(f"An error occurred while processing '{file_path}': {e}")
# Out:
# Dataset 'Datasets/aishihik_lake.csv' loaded successfully.
# Columns in 'Datasets/aishihik_lake.csv': ['Unnamed: 0', 'Unnamed: 1', 'Parasite genus', 'Anonchohaptor', 'Dactylogyrus', 'Discocotyle', 'Tetraonchus', 'Tetraonchus.1', 'Tetraonchus.2', 'Allocreadium', 'Crepidostomum', 'Diplostomum', 'Heterophyid', 'Neascus', 'Tetracotyle', 'Cyathocephalus', 'Diphyllobothrium', 'Eubothrium', 'Glaridacris', 'Proteocephalus', 'Schistocephalus', 'Triaenophorus', 'Triaenophorus.1', 'Capillaria', 'Cystidicola', 'Raphidascaris', 'Raphidascaris.1', 'Neoechinorhynchus', 'Piscicola', 'Salmincola', 'Salmincola.1', 'Salmincola.2']
# Rows after removing missing values: 248
# Rows after removing duplicate edges: 248
# Graph created for 'Datasets/aishihik_lake.csv' with 39 nodes and 248 edges.
# Clustering coefficient for 'Datasets/aishihik_lake.csv': 0.0
# Preprocessed data saved to datacleaning/aishihik_lake_preprocessed.csv
# Dataset 'Datasets/cold_lake.csv' loaded successfully.
# Columns in 'Datasets/cold_lake.csv': ['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Parasite genus', 'Gyrodactylus', 'Discocotyle', 'Diplostomum', 'Apatemon', 'Cotylurus', 'Lissorchis', 'Bunodera', 'Crepidostomum', 'Phyllodistomum', 'Glaridacris', 'Hunterella', 'Cyathocephalus', 'Eubothrium', 'Eubothrium.1', 'Bothriocephalus', 'Diphyllobothrium', 'Schistocephalus', 'Triaenophorus', 'Triaenophorus.1', 'Triaenophorus.2', 'Triaenophorus.3', 'Proteocephalus', 'Proteocephalus.1', 'Proteocephalus.2', 'Proteocephalus.3', 'Raphidascaris', 'Raphidascaris.1', 'Haplonema', 'Philonema', 'Cystidicola', 'Rhabdochona', 'Neoechinorhynchus', 'Metechinorhynchus', 'Pomphorhynchus', 'Cystobranchus', 'Ergasilus', 'Ergasilus.1', 'Ergasilus.2', 'Salmincola', 'Salmincola.1']
# Rows after removing missing values: 473
# Rows after removing duplicate edges: 473
# Graph created for 'Datasets/cold_lake.csv' with 54 nodes and 473 edges.
# Clustering coefficient for 'Datasets/cold_lake.csv': 0.0
# Preprocessed data saved to datacleaning/cold_lake_preprocessed.csv
# Dataset 'Datasets/lake_of_the_woods.csv' loaded successfully.
# Columns in 'Datasets/lake_of_the_woods.csv': ['Unnamed: 0', 'Unnamed: 1', 'Parasite genus', 'Acolpenteron', 'Actinocleidus', 'Anonchohaptor', 'Cleidodiscus', 'Cleidodiscus.1', 'Cleidodiscus.2', 'Cleidodiscus.3', 'Cleidodiscus.4', 'Cleidodiscus.5', 'Cleidodiscus.6', 'Dactylogyrus', 'Dactylogyrus.1', 'Dactylogyrus.2', 'Dactylogyrus.3', 'Discocotyle', 'Gyrodactylus', 'Gyrodactylus.1', 'Gyrodactylus.2', 'Gyrodactylus.3', 'Gyrodactylus.4', 'Octomacrum', 'Octomacrum.1', 'Octomacrum.2', 'Pellucidhaptor', 'Pseudomurraytrema', 'Pseudomurraytrema.1', 'Tetraonchus', 'Allocreadium', 'Allocreadium.1', 'Alloglossidium', 'Alloglossidium.1', 'Apophallus', 'Azygia', 'Azygia.1', 'Bucephalus', 'Bunodera', 'Bunoderina', 'Caecincola', 'Centrovarium', 'Clinostomum', 'Crassiphiala', 'Crepidostomum', 'Crepidostomum.1', 'Crepidostomum.2', 'Crepidostomum.3', 'Cryptogonimus', 'Diplostomum', 'Diplostomum.1', 'Diplostomum.2', 'Diplostomulum', 'Microphallus', 'Neascus', 'Neochasmus', 'Phyllodistomum', 'Phyllodistomum.1', 'Phyllodistomum.2', 'Phyllodistomum.3', 'Phyllodistomum.4', 'Phyllodistomum.5', 'Plagioporus', 'Posthodiplostomum', 'Sanguinicola', 'Tetracotyle', 'Tetracotyle.1', 'Triganodistomum', 'Uvulifer', 'Biacetabulum', 'Biacetabulum.1', 'Bothriocephalus', 'Bothriocephalus.1', 'Bothriocephalus.2', 'Bothriocephalus.3', 'Corallobothrium', 'Cyathocephalus', 'Diphyllobothrium', 'Eubothrium', 'Eubothrium.1', 'Glaridacris', 'Glaridacris.1', 'Glaridacris.2', 'Hunterella', 'Ligula', 'Proteocephalus', 'Proteocephalus.1', 'Proteocephalus.2', 'Proteocephalus.3', 'Proteocephalus.4', 'Proteocephalus.5', 'Proteocephalus.6', 'Proteocephalus.7', 'Proteocephalus.8', 'Schistocephalus', 'Triaenophorus', 'Triaenophorus.1', 'Triaenophorus.2', 'Triaenophorus.3', 'Triaenophorus.4', 'Triaenophorus.5', 'Camallanus', 'Capillaria', 'Capillaria.1', 'Contracaecum', 'Contracaecum.1', 'Contracaecum.2', 'Cystidicola', 'Cystidicola.1', 'Dichelyne', 'Eustrongylides', 'Philometra', 'Philometra.1', 'Rhabdochona', 'Spinitectus', 'Spinitectus.1', 'Spiroxys', 'Leptorhynchoides', 'Leptorhynchoides.1', 'Metechinorhynchus', 'Metechinorhynchus.1', 'Neoechinorhynchus', 'Neoechinorhynchus.1', 'Neoechinorhynchus.2', 'Neoechinorhynchus.3', 'Neoechinorhynchus.4', 'Neoechinorhynchus.5', 'Neoechinorhynchus.6', 'Neoechinorhynchus.7', 'Octospinifer', 'Pomphorhynchus', 'Actinobdella', 'Illinobdella', 'Illinobdella.1', 'Piscicola', 'Achtheres', 'Achtheres.1', 'Ergasilus', 'Ergasilus.1', 'Ergasilus.2', 'Ergasilus.3', 'Ergasilus.4', 'Salmincola', 'Argulus', 'Argulus.1', 'Argulus.2', 'Argulus.3']
# Rows after removing missing values: 4672
# Rows after removing duplicate edges: 4672
# Graph created for 'Datasets/lake_of_the_woods.csv' with 178 nodes and 4672 edges.
# Clustering coefficient for 'Datasets/lake_of_the_woods.csv': 0.0
# Preprocessed data saved to datacleaning/lake_of_the_woods_preprocessed.csv
# Dataset 'Datasets/mcgregor_river.csv' loaded successfully.
# Columns in 'Datasets/mcgregor_river.csv': ['Unnamed: 0', 'Unnamed: 1', 'Parasite genus', 'Acolpenteron', 'Anoncohaptor', 'Pseudomurraytrema', 'Tetraonchus', 'Tetraonchus.1', 'Octomacrum', 'Octomacrum.1', 'Allocreadium', 'Bunodera', 'Crepidostomum', 'Phyllodistomum', 'Brachyphallus', 'Genolinea', 'Lampritrema', 'Diplostomum', 'Diplostomum.1', 'Neascus', 'Tetracotyle', 'Glaridacris', 'Proteocephalus', 'Proteocephalus.1', 'Proteocephalus.2', 'Proteocephalus.3', 'Bothriocephalus', 'Diphyllobothrium', 'Eubothrium', 'Ligula', 'Phyllobothrium', 'Hysterothylacium', 'Eustrongylides', 'Philometroides', 'Philonema', 'Philonema.1', 'Philonema.2', 'Haplonema', 'Cystidicola', 'Cystidicoloides', 'Rhabdochona', 'Rhabdochona.1', 'Rhabdochona.2', 'Rhabdochona.3', 'Rhabdochona.4', 'Rhabdochona.5', 'Neoechinorhynchus', 'Neoechinorhynchus.1', 'Octospinifer', 'Ergasilus', 'Salmincola', 'Salmincola.1', 'Salmincola.2', 'Salmincola.3']
# Rows after removing missing values: 848
# Rows after removing duplicate edges: 848
# Graph created for 'Datasets/mcgregor_river.csv' with 69 nodes and 848 edges.
# Clustering coefficient for 'Datasets/mcgregor_river.csv': 0.0
# Preprocessed data saved to datacleaning/mcgregor_river_preprocessed.csv
# Dataset 'Datasets/parsnip_river.csv' loaded successfully.
# Columns in 'Datasets/parsnip_river.csv': ['Unnamed: 0', 'Unnamed: 1', 'Parasite genus', 'Acolpenteron', 'Anoncohaptor', 'Pellucidhaptor', 'Pseudomurraytrema', 'Tetraonchus', 'Tetraonchus.1', 'Octomacrum', 'Allocreadium', 'Bunodera', 'Crepidostomum', 'Phyllodistomum', 'Diplostomum', 'Diplostomum.1', 'Neascus', 'Tetracotyle', 'Glaridacris', 'Glaridacris.1', 'Glaridacris.2', 'Hunterella', 'Monobothrium', 'Proteocephalus', 'Proteocephalus.1', 'Proteocephalus.2', 'Proteocephalus.3', 'Bothriocephalus', 'Diphyllobothrium', 'Eubothrium', 'Ligula', 'Hysterothylacium', 'Raphidascaris', 'Eustrongylides', 'Philometroides', 'Philonema', 'Philonema.1', 'Haplonema', 'Truttaedacnitis', 'Cystidicola', 'Cystidicoloides', 'Rhabdochona', 'Rhabdochona.1', 'Rhabdochona.2', 'Rhabdochona.3', 'Rhabdochona.4', 'Rhabdochona.5', 'Neoechinorhynchus', 'Neoechinorhynchus.1', 'Neoechinorhynchus.2', 'Octospinifer', 'Pomphorhynchus', 'Ergasilus', 'Salmincola', 'Salmincola.1', 'Salmincola.2']
# Rows after removing missing values: 990
# Rows after removing duplicate edges: 990
# Graph created for 'Datasets/parsnip_river.csv' with 73 nodes and 990 edges.
# Clustering coefficient for 'Datasets/parsnip_river.csv': 0.0
# Preprocessed data saved to datacleaning/parsnip_river_preprocessed.csv
# Dataset 'Datasets/sbay_lake_huron.csv' loaded successfully.
# Columns in 'Datasets/sbay_lake_huron.csv': ['Unnamed: 0', 'Unnamed: 1', 'Parasite genus', 'Discocotyle', 'Octomacrum', 'Triganodistomum', 'Triganodistomum.1', 'Bucephalus', 'Bunodera', 'Bunoderina', 'Bucephalus.1', 'Bucephalopsis', 'Caecincola', 'Allocreadium', 'Acetodextra', 'Azygia', 'Azygia.1', 'Lebouria', 'Microphallus', 'Protometra', 'Plagioporus', 'Crepidostomum', 'Crepidostomum.1', 'Crepidostomum.2', 'Crepidostomum.3', 'Crepidostomum.4', 'Centrovarium', 'Centrovarium.1', 'Cryptogonimus', 'Clinostomum', 'Rhipidocotyle', 'Tetracotyle', 'Neascus', 'Diplostomulum', 'Diplostomum', 'Posthodiplostomum', 'Glaridacris', 'Abothrium', 'Bothriocephalus', 'Bothriocephalus.1', 'Bothriocephalus.2', 'Bothriocephalus.3', 'Eubothrium', 'Corallobothrium', 'Cyathocephalus', 'Diphyllobothrium', 'Ligula', 'Triaenophorus', 'Triaenophorus.1', 'Triaenophorus.2', 'Proteocephalus', 'Proteocephalus.1', 'Proteocephalus.2', 'Proteocephalus.3', 'Proteocephalus.4', 'Proteocephalus.5', 'Camallanus', 'Philometra', 'Philometra.1', 'Metabronema', 'Contracaecum', 'Cystidicola', 'Dichelyne', 'Dichelyne.1', 'Dichelyne.2', 'Haplonema', 'Hepaticola', 'Rhabdochona', 'Rhabdochona.1', 'Spiroxys', 'Spinitectus', 'Spinitectus.1', 'Spinitectus.2', 'Spinitectus.3', 'Echinorhynchus', 'Echinorhynchus.1', 'Echinorhynchus.2', 'Leptorhynchoides', 'Neoechinorhynchus', 'Neoechinorhynchus.1', 'Neoechinorhynchus.2', 'Neoechinorhynchus.3', 'Neoechinorhynchus.4', 'Neoechinorhynchus.5', 'Octospinifer', 'Pomphorhynchus', 'Pomphorhynchus.1', 'Actinobdella', 'Illinobdella', 'Illinobdella.1', 'Illinobdella.2', 'Achtheres', 'Achtheres.1', 'Achtheres.2', 'Achtheres.3', 'Ergasilus', 'Salmincola', 'Salmincola.1', 'Salmincola.2', 'Argulus']
# Rows after removing missing values: 3366
# Rows after removing duplicate edges: 3366
# Graph created for 'Datasets/sbay_lake_huron.csv' with 133 nodes and 3366 edges.
# Clustering coefficient for 'Datasets/sbay_lake_huron.csv': 0.0
# Preprocessed data saved to datacleaning/sbay_lake_huron_preprocessed.csv
# Dataset 'Datasets/smallwood_reservoir.csv' loaded successfully.
# Columns in 'Datasets/smallwood_reservoir.csv': ['Unnamed: 0', 'Unnamed: 1', 'Parasite genus', 'Tetraonchus', 'Discocotyle', 'Crepidostomum', 'Crepidostomum.1', 'Phyllodistomum', 'Phyllodistomum.1', 'Triaenophorus', 'Triaenophorus.1', 'Eubothrium', 'Diphyllobothrium', 'Proteocephalus', 'Proteocephalus.1', 'Proteocephalus.2', 'Proteocephalus.3', 'Raphidascaris', 'Raphidascaris.1', 'Capillaria', 'Metabronema', 'Metechinorhynchus', 'Neoechinorhynchus', 'Ergasilus', 'Salmincola', 'Salmincola.1', 'Salmincola.2', 'Salmincola.3']
# Rows after removing missing values: 189
# Rows after removing duplicate edges: 189
# Graph created for 'Datasets/smallwood_reservoir.csv' with 34 nodes and 189 edges.
# Clustering coefficient for 'Datasets/smallwood_reservoir.csv': 0.0
# Preprocessed data saved to datacleaning/smallwood_reservoir_preprocessed.csv

# %%
import pandas as pd
import networkx as nx
import os

# List of dataset file paths
file_paths = [
    "Datasets/AkatoreA.csv",
    "Datasets/AkatoreB.csv",
    "Datasets/Venlaw.csv",
]

# Ensure the output directory exists
output_dir = "datacleaning"
os.makedirs(output_dir, exist_ok=True)

# Loop through each dataset and preprocess
for file_path in file_paths:
    try:
        # Load the dataset
        data = pd.read_csv(file_path)
        print(f"Dataset '{file_path}' loaded successfully.")
        
        # Check columns in the dataset
        print(f"Columns in '{file_path}': {data.columns.tolist()}")
        
        # Step 1: Handle missing or incorrect 'Parasite genus' column
        # If 'Unnamed: 0' is the column holding genus names, use it as the source
        if 'Unnamed: 0' not in data.columns:
            print(f"Error: 'Unnamed: 0' column not found in {file_path}. Skipping this dataset.")
            continue
        
        # Step 2: Restructure data into long format (using the first column for the 'source')
        data_long = data.melt(id_vars=["Unnamed: 0"], 
                              var_name="target", 
                              value_name="weight")
        
        # Rename columns for clarity
        data_long = data_long.rename(columns={"Unnamed: 0": "source"})
        
        # Step 3: Drop rows with missing values
        data_long = data_long.dropna()
        print(f"Rows after removing missing values: {len(data_long)}")
        
        # Step 4: Drop duplicate edges
        data_long = data_long.drop_duplicates(subset=["source", "target"])
        print(f"Rows after removing duplicate edges: {len(data_long)}")
        
        # Step 5: Create a directed graph
        G = nx.from_pandas_edgelist(data_long, source="source", target="target", create_using=nx.DiGraph())
        print(f"Graph created for '{file_path}' with {G.number_of_nodes()} nodes and {G.number_of_edges()} edges.")
        
        # Step 6: Calculate clustering coefficient
        # If the graph is directed, we calculate the clustering coefficient for the directed graph
        if isinstance(G, nx.DiGraph):
            clustering_coeffs = nx.clustering(G.to_undirected())  # Convert to undirected for clustering
        else:
            clustering_coeffs = nx.clustering(G)  # For undirected graphs
        
        # Calculate the average clustering coefficient
        avg_clustering_coeff = sum(clustering_coeffs.values()) / len(clustering_coeffs)
        print(f"Clustering coefficient for '{file_path}': {avg_clustering_coeff}")
        
        # Step 7: Save the preprocessed data
        output_path = os.path.join(output_dir, f"{file_path.split('/')[-1].replace('.csv', '_preprocessed.csv')}")
        data_long.to_csv(output_path, index=False)
        print(f"Preprocessed data saved to {output_path}")
    
    except Exception as e:
        print(f"An error occurred while processing '{file_path}': {e}")
# Out:
# Dataset 'Datasets/AkatoreA.csv' loaded successfully.
# Columns in 'Datasets/AkatoreA.csv': ['Unnamed: 0', 'Unidentified detritus', 'Terrestrial invertebrates', 'Plant materials', 'Meiofauna', 'Achnanthes inflata', 'Achnanthes lanceolata', 'Achnanthes linearis', 'Achnanthes minutissima', 'Ankitodesmus sp.', 'Batrachospermum', 'Blue-green algae', 'Calothrix', 'Cocconeis placentula', 'Cymbella kappi', 'Cymbella kappii', 'Cymbella mulleri', 'Diatoma heimale', 'Epithemia sorex', 'Eunotia pectinalis', 'Fragilaria vaucheriae', 'Frustulia rhomboides', 'Gomphoneis herculeana', 'Gomphonema accuminatum', 'Gomphonema angustatum', 'Gomphonema intricatum', 'Gomphonema parvulum', 'Gomphonema sp. III', 'Gomphonema sp. unk', 'Gomphonema truncatum', 'Green algae', 'Gyrosigma', 'Melosira varians', 'Navicula avenacea', 'Navicula rhynocephala', 'Nitzschia dissipata', 'Nitzschia dubia', 'Nitzschia linearis', 'Pinnularia spp.', 'Rhoicosphenia curvata', 'Staurostratum', 'Surirella elegans', 'Synedra ulna', 'Tabellaria flocculosa', 'Ulothrix', 'Ameletopsis perscitus (N=13)', 'Aoteapsyche raruraru (N=8)', 'Austroperla cyrene (N=15)', 'Austrosimulium australense (N=4)', 'Chironomini (N=Cricotopus)', 'Coloburiscus humeralis (N=5)', 'Costachorema xanthoptera (N=3)', 'Cricotopus sp I (N=6)', 'Cricotopus sp II (N=1)', 'Cristaperla (N=15)', 'Deleatidium (N=15)', 'Eriopterini (N=6)', 'Eye forward chiron (N=1)', 'Helicopsyche albescens (N=3)', 'Hudsonema aliena (N=2)', 'Hudsonema amabilis (N=12)', 'Hydora nitida (ad) (N=15)', 'Hydora nitida (l) (N=15)', 'Hydrobiosella stenocerca (N=15)', 'Hydrobiosis parumbripennis (N=Chostachorema)', 'Mischoderus (N=1)', 'Nannochorista phillpotti (N=1)', 'Neozephlebia scita (N=10)', 'Oligo II (N=3)', 'Oligo Lumbri pink (N=10)', 'Oligo skinny (N=10)', 'Paracalliope fluviatalus (N=10)', 'Paracalliope pale (N=10)', 'Paralimnophila skuseii (N=3)', 'Paucispinigera approximata (N=1)', 'Polypedellum (N=4)', 'Polypedellum II (N=1)', 'Polyplectropus puerilis (N=1)', 'Scirtid broad spp. (N=2)', 'Sphaerid (N=1)', 'Stenoperla prasinia (N=10)', 'Stictocladius (N=2)', 'Zelandobius (N=2)', 'Zelandoperla fenestrata (N=10)', 'Zelandotipula (N=1)', 'Anguilla dieffenbachii (N=1)']
# Rows after removing missing values: 7225
# Rows after removing duplicate edges: 7225
# Graph created for 'Datasets/AkatoreA.csv' with 126 nodes and 7225 edges.
# Clustering coefficient for 'Datasets/AkatoreA.csv': 0.7766214155913242
# Preprocessed data saved to datacleaning/AkatoreA_preprocessed.csv
# Dataset 'Datasets/AkatoreB.csv' loaded successfully.
# Columns in 'Datasets/AkatoreB.csv': ['Unnamed: 0', 'Unidentified detritus', 'Plant material', 'Terrestrial invertebrates ', 'Achnanthes inflata', 'Achnanthes lanceolata', 'Achnanthes linearis', 'Achnanthes minutissima', 'Blue green algae', 'Calothrix', 'Cocconeis placentula', 'Cymbella aspera', 'Cymbella kappi', 'Eunotia pectinalis', 'Frustulia rhomboides', 'Gomphoneis herculeana', 'Gomphonema angustatum', 'Gomphonema truncatum', 'Melosira varians', 'Navicula avenacea', 'Pinnularia divergens', 'Pinnularia gibba', 'Pinnularia sp.', 'Pinnularia viridis', 'Rhoicosphenia curvata', 'Surirella elegans', 'Surirella striatula', 'Synedra rumpens', 'Tabellaria flocculosa', 'Unknown green algal cells', 'Ameletopsis perscitus (N=10)', 'Aspectrotanypus (N=Larsia)', 'Austroperla cyrene (N=5)', 'Coloburiscus humeralis (N=1)', 'Cricotopus II (N=8)', 'Cristaperla fimbriae (N=10)', 'Deleatidium spp. (N=10)', 'Eriopterini (N=4)', 'Eukiefiriella (N=3)', 'Forcipomyiinae (N=1)', 'Hydora adult (N=10)', 'Hydora nitida l (N=Hydora adult', 'Hydrobiosella stenocerca (N=10)', 'Larsia sp. (N=1)', 'Naonella forysthii (N=9)', 'Oligochaeta I  (N=10)', 'Oligochaeta II (N=8)', 'Oligochaeta lumbr blue (N=10)', 'Paracalliope fluviatalus (N=10)', 'Paralimnophila (N=1)', 'Patatanytarsus nr grimmi (N=Tanytarsus)', 'Paucispinigera approximata (N=8)', 'Polypedellum green type (N=8)', 'Stenoperla prasinia (N=10)', 'Stictocladius (N=10)', 'Tanytarsus spp. (N=3)', 'Tanytarsus verspertinus (N=3)', 'Zelanoperla fenestrata (N=10)', 'Crayfish (N=9)']
# Rows after removing missing values: 3364
# Rows after removing duplicate edges: 3364
# Graph created for 'Datasets/AkatoreB.csv' with 88 nodes and 3364 edges.
# Clustering coefficient for 'Datasets/AkatoreB.csv': 0.7465783910092355
# Preprocessed data saved to datacleaning/AkatoreB_preprocessed.csv
# Dataset 'Datasets/Venlaw.csv' loaded successfully.
# Columns in 'Datasets/Venlaw.csv': ['Unnamed: 0', 'Terrestrial invertebrate remains', 'Terrestrial plant material', 'Unidentified organic detritus', 'Achnanthes lanceolata', 'Cocconeis placentual', 'Cymbella aspera', 'Epithemis turgida', 'Fragilaria vaucheriae', 'Frustulia rhomboides', 'Gomphoneis herculeana var. robusta', 'Gomphonema angustatum', 'Gomphonema parvulum', 'Gomphonema sp. II', 'Gomphonema subclavatum', 'Gomphonema truncatum', 'Melosira granulata', 'Navicula avenacea', 'Navicula placentula', 'Nitzschia linearis', 'Pinnularia borealis', 'Rhoicosphenia curvata', 'Surirella elegans', 'Synedra rumpens', 'Synedra ulna', 'Tabellaria flocculosa', 'Batrachospermum spp.', 'Blue-green algae', 'Cyclotella sp.', 'Oedogonium spp.', 'Ulothrix spp.', 'Unknown green algae', 'Ameletopsis perscitus (N=1)', "Amphipoda type 'purple' (N=6)", 'Aoteapsyche raruraru (N=Hydrobiosis sp.)', 'Aphrophila neozelandica (N=10)', 'Austroperla cyrene (N=7)', 'Austrosimulium australense (N=8)', 'Coloburiscus humeralis', "Cricotopus sp. Type  'pale' (N=10)", 'Cristaperla fimbria (N=1)', 'Deleatidum lilli (N=11)', 'Eukieffidriella  brundini (N=9)', 'Hudsonema amabilis (N=1)', 'Hydora nitida (N=10)', 'Hydraena homolaena (N=1)', ' Hydrobiosella stenocerca (N=2) ', 'Hydrobiosis sp. (N=1)', 'Hydrophilidae (N=1)', 'Isopoda (N=1)', "Lumbriculiid type 'II' (N=10)", 'Maoridiamesia sp. (N=10)', 'Megaleptoperla grandis (N=3)', 'Naonella forsythii (N=9)', 'Paracalliope  fluviatalus (N=8)', 'Podaena sp. (N=1)', 'Potamopyrgus antipodarum (N=Deleatidium lilli)', 'Pycnocentria evecta (N=4)', 'Rhabdomastrix sp. (N=2)', 'Scirtidae broad (N=3)', 'Stenoperla prasinia (N=3)', 'Stictocladius sp. (N=5)', 'Tanypodini sp. (N=1)', 'Tanytarsini sp. (N=7)', 'Tiphobiosis montata (N=1)', 'Zelandobius confusus (N=4)', 'Zelandoperla fenestrata (N=10)', 'Paranephrops zelandicus (N=4)', 'Salmo trutta (N=3)', 'Galaxias brevipennis (N=1)']
# Rows after removing missing values: 4761
# Rows after removing duplicate edges: 4761
# Graph created for 'Datasets/Venlaw.csv' with 106 nodes and 4761 edges.
# Clustering coefficient for 'Datasets/Venlaw.csv': 0.7281673015012791
# Preprocessed data saved to datacleaning/Venlaw_preprocessed.csv
