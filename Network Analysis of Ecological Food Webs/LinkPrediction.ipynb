# %%
import networkx as nx
import pandas as pd

# List of file paths
file_paths = [
    'datacleaning/aishihik_lake_preprocessed.csv',
    'datacleaning/AkatoreA_preprocessed.csv',
    'datacleaning/AkatoreB_preprocessed.csv',
    'datacleaning/cold_lake_preprocessed.csv',
    'datacleaning/lake_of_the_woods_preprocessed.csv',
    'datacleaning/mcgregor_river_preprocessed.csv',
    'datacleaning/parsnip_river_preprocessed.csv',
    'datacleaning/sbay_lake_huron_preprocessed.csv',
    'datacleaning/smallwood_reservoir_preprocessed.csv',
    'datacleaning/Venlaw_preprocessed.csv'
]

def calculate_network_properties_and_links(file_path):
    """Calculate network properties and predict links."""
    try:
        # Load preprocessed data
        edge_list = pd.read_csv(file_path)
        G = nx.from_pandas_edgelist(edge_list, source="source", target="target")
        
        # Network properties
        num_nodes = G.number_of_nodes()
        num_edges = G.number_of_edges()

        # Link prediction (Common Neighbors)
        link_pred_scores = [
            (u, v, len(list(nx.common_neighbors(G, u, v))))
            for u, v in nx.non_edges(G)
        ]
        link_pred_scores_sorted = sorted(link_pred_scores, key=lambda x: x[2], reverse=True)[:5]

        # Print results
        print(f"Results for {file_path}:")
        print(f"  Number of nodes: {num_nodes}")
        print(f"  Number of edges: {num_edges}")
        print("  Top 5 predicted links (Common Neighbors):")
        for u, v, score in link_pred_scores_sorted:
            print(f"    ({u}, {v}) - Score: {score}")
        print("-" * 50)

    except Exception as e:
        print(f"An error occurred with '{file_path}': {e}")

# Loop through all files and calculate properties, printing the results
for file_path in file_paths:
    result = calculate_network_properties(file_path)
    print(result)
# Out:
#     Results for datacleaning/aishihik_lake_preprocessed.csv:
#     ------------------------------
#       Number of nodes (species): 39
#       Number of edges (interactions): 248
#
# Top 5 Predicted Links (based on Common Neighbors):
#       (Salvelinus namaycush, Esox lucius) - Prediction Score: 31
#       (Salvelinus namaycush, Thymallus arcticus) - Prediction Score: 31
#       (Salvelinus namaycush, Catostomus catostomus) - Prediction Score: 31
#       (Salvelinus namaycush, Coregonus clupeaformis) - Prediction Score: 31
#       (Salvelinus namaycush, Cottus cognatus) - Prediction Score: 31
# --------------------------------------------------
#
#
#     Results for datacleaning/AkatoreA_preprocessed.csv:
#     ------------------------------
#       Number of nodes (species): 126
#       Number of edges (interactions): 6279
#
# Top 5 Predicted Links (based on Common Neighbors):
#       (Hydrobiosis parumbripennis, Neozephlebia scita) - Prediction Score: 85
#       (Hydrobiosis parumbripennis, Polypedellum) - Prediction Score: 85
#       (Hydrobiosis parumbripennis, Anguilla dieffenbachii) - Prediction Score: 85
#       (Hydrobiosis parumbripennis, Cristaperla) - Prediction Score: 85
#       (Hydrobiosis parumbripennis, Hydrobiosella stenocerca) - Prediction Score: 85
# --------------------------------------------------
#
#
#     Results for datacleaning/AkatoreB_preprocessed.csv:
#     ------------------------------
#       Number of nodes (species): 88
#       Number of edges (interactions): 2986
#
# Top 5 Predicted Links (based on Common Neighbors):
#       (
#
# Top 5 Predicted Links (based on Common Neighbors):
#       (Salvelinus namaycush, Esox lucius) - Prediction Score: 27
#       (Salvelinus namaycush, Catostomus catostomus) - Prediction Score: 27
#       (Salvelinus namaycush, Salvelinus fontinalis) - Prediction Score: 27
#       (Salvelinus namaycush, Coregonus clupeaformis) - Prediction Score: 27
#       (Salvelinus namaycush, Salmo salar) - Prediction Score: 27
# --------------------------------------------------
#
#
#     Results for datacleaning/Venlaw_preprocessed.csv:
#     ------------------------------
#       Number of nodes (species): 106
#       Number of edges (interactions): 4265
#
# Top 5 Predicted Links (based on Common Neighbors):
#       (Maoridiamesia sp., Cristaperla fimbria) - Prediction Score: 69
#       (Maoridiamesia sp., Hydrobiosella stenocerca) - Prediction Score: 69
#       (Maoridiamesia sp., Scirtidae type 'broad') - Prediction Score: 69
#       (Maoridiamesia sp., Salmo trutta) - Prediction Score: 69
#       (Maoridiamesia sp., Megaleptoperla grandis) - Prediction Score: 69
# --------------------------------------------------

# %%
import pandas as pd
import networkx as nx

def calculate_network_properties_and_links(file_path):
    """Calculate network properties and predict links."""
    try:
        # Load preprocessed data
        edge_list = pd.read_csv(file_path)
        G = nx.from_pandas_edgelist(edge_list, source="source", target="target")
        
        # Network properties
        num_nodes = G.number_of_nodes()
        num_edges = G.number_of_edges()

        # Link prediction (Common Neighbors)
        link_pred_scores = [
            (u, v, len(list(nx.common_neighbors(G, u, v))))
            for u, v in nx.non_edges(G)
        ]
        link_pred_scores_sorted = sorted(link_pred_scores, key=lambda x: x[2], reverse=True)[:5]

        # Print results
        print(f"Results for {file_path}:")
        print(f"  Number of nodes: {num_nodes}")
        print(f"  Number of edges: {num_edges}")
        print("  Top 5 predicted links (Common Neighbors):")
        for u, v, score in link_pred_scores_sorted:
            print(f"    ({u}, {v}) - Score: {score}")
        print("-" * 50)

    except Exception as e:
        print(f"An error occurred with '{file_path}': {e}")

# List of preprocessed file paths
file_paths = [
    "datacleaning/aishihik_lake_preprocessed.csv",
    "datacleaning/cold_lake_preprocessed.csv",
    "datacleaning/lake_of_the_woods_preprocessed.csv",
    "datacleaning/mcgregor_river_preprocessed.csv",
    "datacleaning/parsnip_river_preprocessed.csv",
    "datacleaning/sbay_lake_huron_preprocessed.csv",
    "datacleaning/smallwood_reservoir_preprocessed.csv",
]

# Process each file
for file_path in file_paths:
    calculate_network_properties_and_links(file_path)
# Out:
# Results for datacleaning/aishihik_lake_preprocessed.csv:
#   Number of nodes: 39
#   Number of edges: 248
#   Top 5 predicted links (Common Neighbors):
#     (Salvelinus namaycush, Esox lucius) - Score: 31
#     (Salvelinus namaycush, Thymallus arcticus) - Score: 31
#     (Salvelinus namaycush, Catostomus catostomus) - Score: 31
#     (Salvelinus namaycush, Coregonus clupeaformis) - Score: 31
#     (Salvelinus namaycush, Cottus cognatus) - Score: 31
# --------------------------------------------------
# Results for datacleaning/cold_lake_preprocessed.csv:
#   Number of nodes: 54
#   Number of edges: 473
#   Top 5 predicted links (Common Neighbors):
#     (Stizostedion vitreum, Esox lucius) - Score: 43
#     (Stizostedion vitreum, Coregonus artedii) - Score: 43
#     (Stizostedion vitreum, Salvelinus namaycush) - Score: 43
#     (Stizostedion vitreum, Catostomus catostomus) - Score: 43
#     (Stizostedion vitreum, Lota lota) - Score: 43
# --------------------------------------------------
# Results for datacleaning/lake_of_the_woods_preprocessed.csv:
#   Number of nodes: 178
#   Number of edges: 4672
#   Top 5 predicted links (Common Neighbors):
#     (Notropis atherinoides, Stizostedion canadense) - Score: 146
#     (Notropis atherinoides, Semotilus margarita) - Score: 146
#     (Notropis atherinoides, Stizostedion vitreum) - Score: 146
#     (Notropis atherinoides, Culaea inconstans) - Score: 146
#     (Notropis atherinoides, Notropis hudsonius) - Score: 146
# --------------------------------------------------
# Results for datacleaning/mcgregor_river_preprocessed.csv:
#   Number of nodes: 69
#   Number of edges: 848
#   Top 5 predicted links (Common Neighbors):
#     (Catostomus macrocheilus, Salvelinus malma) - Score: 53
#     (Catostomus macrocheilus, Rhinichthys cataractae) - Score: 53
#     (Catostomus macrocheilus, Richardsonius balteatus) - Score: 53
#     (Catostomus macrocheilus, Salvelinus namaycush) - Score: 53
#     (Catostomus macrocheilus, Catostomus catostomus) - Score: 53
# --------------------------------------------------
# Results for datacleaning/parsnip_river_preprocessed.csv:
#   Number of nodes: 73
#   Number of edges: 990
#   Top 5 predicted links (Common Neighbors):
#     (Catostomus macrocheilus, Salvelinus malma) - Score: 55
#     (Catostomus macrocheilus, Prosopium coulteri) - Score: 55
#     (Catostomus macrocheilus, Rhinichthys cataractae) - Score: 55
#     (Catostomus macrocheilus, Richardsonius balteatus) - Score: 55
#     (Catostomus macrocheilus, Salvelinus namaycush) - Score: 55
# --------------------------------------------------
# Results for datacleaning/sbay_lake_huron_preprocessed.csv:
#   Number of nodes: 133
#   Number of edges: 3366
#   Top 5 predicted links (Common Neighbors):
#     (Notropis atherinoides, Stizostedion vitreum) - Score: 99
#     (Notropis atherinoides, Culaea inconstans) - Score: 99
#     (Notropis atherinoides, Notropis hudsonius) - Score: 99
#     (Notropis atherinoides, Micropterus dolomieui) - Score: 99
#     (Notropis atherinoides, Coregonus artedi) - Score: 99
# --------------------------------------------------
# Results for datacleaning/smallwood_reservoir_preprocessed.csv:
#   Number of nodes: 34
#   Number of edges: 189
#   Top 5 predicted links (Common Neighbors):
#     (Salvelinus namaycush, Esox lucius) - Score: 27
#     (Salvelinus namaycush, Catostomus catostomus) - Score: 27
#     (Salvelinus namaycush, Salvelinus fontinalis) - Score: 27
#     (Salvelinus namaycush, Coregonus clupeaformis) - Score: 27
#     (Salvelinus namaycush, Salmo salar) - Score: 27
# --------------------------------------------------
